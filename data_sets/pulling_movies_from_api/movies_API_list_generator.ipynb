# %%
#imports
import pandas as pd
import requests
import time

# %%
#Created seperate CSVs with movie lists due to API limitations
CSV1 = 'Movies.csv'
CSV2 = 'Movies2.csv'
CSV3 = 'Movies3.csv'
CSV4 = 'Movies4.csv'
CSV5 = 'Movies5.csv'
CSV6 = 'Movies6.csv'

#URL for API with API Key
url2 = "http://www.omdbapi.com/?apikey=trilogy&t="
url3 = "http://www.omdbapi.com/?apikey=5d43599&t="


#Create DF with CSV Files
DF = pd.read_csv(CSV1)
DF2 = pd.read_csv(CSV2)
DF3 = pd.read_csv(CSV3)
DF4 = pd.read_csv(CSV4)
DF5 = pd.read_csv(CSV5)
DF6 = pd.read_csv(CSV6)

# %%
#Pull only the titles from the CSVs and create a list
titles = DF["Title"].values.tolist()
titles2 = DF2["Title"].values.tolist()
titles3 = DF3["Title"].values.tolist()
titles4 = DF4["Title"].values.tolist()
titles5 = DF5["Title"].values.tolist()
titles6 = DF6["Title"].values.tolist()

# %%
#create an empty list for the responses
responses = [];

#loop through the api and pull the data for each of the movies from the CSV, we have a pause added 
for i in range(0, len(titles)):
    movie_data = requests.get(url2 + titles[i]).json()
    responses.append(movie_data)
    if i % 500 == 0:
        print("Collected " + str(i) + " movies.")
        time.sleep(5)
# Out:
# Collected 0 movies.
# Collected 500 movies.

# %%
#create an empty list for the responses
responses2 = [];

#loop through the api and pull data for reach of the movies for the second csv, we have a pause added
for i in range(0, len(titles2)):
    movie_data = requests.get(url2 + titles2[i]).json()
    responses2.append(movie_data)
    if i % 500 == 0:
        print("Collected " + str(i) + " movies.")
        time.sleep(5)
# Out:
# Collected 0 movies.
# Collected 500 movies.
# Collected 1000 movies.

# %%
#create an empty list for the responses
responses3 = [];

#loop through the api and pull data for reach of the movies for the third csv, we have a pause added
for i in range(0, len(titles3)):
    movie_data = requests.get(url2 + titles3[i]).json()
    responses3.append(movie_data)
    if i % 500 == 0:
        print("Collected " + str(i) + " movies.")
        time.sleep(5)
# Out:
# Collected 0 movies.
# Collected 500 movies.
# Collected 1000 movies.

# %%
#create an empty list for the responses
responses4 = [];

#loop through the api and pull data for reach of the movies for the fourth csv, we have a pause added
for i in range(0, len(titles4)):
    movie_data = requests.get(url2 + titles4[i]).json()
    responses4.append(movie_data)
    if i % 500 == 0:
        print("Collected " + str(i) + " movies.")
        time.sleep(5)
# Out:
# Collected 0 movies.
# Collected 500 movies.
# Collected 1000 movies.

# %%
#create an empty list for the responses
responses5 = [];

#loop through the api and pull data for reach of the movies for the fifth csv, we have a pause added
for i in range(0, len(titles5)):
    movie_data = requests.get(url2 + titles5[i]).json()
    responses5.append(movie_data)
    if i % 500 == 0:
        print("Collected " + str(i) + " movies.")
        time.sleep(5)
# Out:
# Collected 0 movies.
# Collected 500 movies.
# Collected 1000 movies.

# %%
#create an empty list for the responses
responses6 = [];

#loop through the api and pull data for reach of the movies for the fifth csv, we have a pause added
for i in range(0, len(titles6)):
    movie_data = requests.get(url2 + titles6[i]).json()
    responses6.append(movie_data)
    if i % 500 == 0:
        print("Collected " + str(i) + " movies.")
        time.sleep(5)
# Out:
# Collected 0 movies.
# Collected 500 movies.
# Collected 1000 movies.

# %%
responses
# Out:
# [{'Actors': 'Tim Roth, Amanda Plummer, Laura Lovelace, John Travolta',
#   'Awards': 'Won 1 Oscar. Another 62 wins & 69 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '19 May 1998',
#   'Director': 'Quentin Tarantino',
#   'Genre': 'Crime, Drama',
#   'Language': 'English, Spanish, French',
#   'Metascore': '94',
#   'Plot': "The lives of two mob hitmen, a boxer, a gangster's wife, and a pair of diner bandits intertwine in four tales of violence and redemption.",
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNGNhMDIzZTUtNTBlZi00MTRlLWFjM2ItYzViMjE3YzI5MjljXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SX300.jpg',
#   'Production': 'Miramax Films',
#   'Rated': 'R',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.9/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '94%'},
#    {'Source': 'Metacritic', 'Value': '94/100'}],
#   'Released': '14 Oct 1994',
#   'Response': 'True',
#   'Runtime': '154 min',
#   'Title': 'Pulp Fiction',
# ...

# %%
#empty lists for the data 
Title = []
Year = []
Rated = []
Released = []
Runtime = []
Genre = []
Director = []
Writer = []
Actors = []
Plot = []
Language = []
Country = []
Poster = []
IMDB = []
RottenTomatoes = []
Metacritic = []
BoxOffice = []
Type = []
Production = []

# %%
#Pulls data from the json file (response) and adds the data into the empty lists 
for data in responses:
   if data["Response"] == "True":
        try:
            Title.append(data["Title"])
        except:
            Title.append('N/A')
        try:        
            Year.append(data["Year"])
        except:
            Year.append('N/A')
        try:        
            Rated.append(data["Rated"])
        except:
            Rated.append('N/A')        
        try:        
            Released.append(data["Released"])
        except:
            Released.append('N/A')     
        try:        
            Runtime.append(data["Runtime"])
        except:
            Runtime.append('N/A')   
        try:
            Genre.append(data["Genre"])
        except:
            Genre.append('N/A')
        try:
            Director.append(data["Director"])
        except:
            Director.append('N/A')
        try:
            Writer.append(data["Writer"])
        except:
            Writer.append('N/A')   
        try:
            Actors.append(data["Actors"])
        except:
            Actors.append('N/A')
        try:
            Language.append(data["Language"])
        except:
            Language.append('N/A')            
        try:
            Country.append(data["Country"])
        except:
            Country.append('N/A')
        try:
            IMDB.append(data["Ratings"][0]["Value"])
        except:
            IMDB.append('N/A')
        try:
            RottenTomatoes.append(data["Ratings"][1]["Value"])
        except:
            RottenTomatoes.append('N/A')
        try:
            Metacritic.append(data["Ratings"][2]["Value"])
        except:
            Metacritic.append('N/A')
        try:
            Type.append(data["Type"])
        except:
            Type.append('N/A')
        try:
            BoxOffice.append(data["BoxOffice"])
        except:
            BoxOffice.append('N/A')
        try:
            Production.append(data["Production"])
        except:
            Production.append('N/A')

# %%
#Pulls data from the json file (response) and adds the data into the empty lists 
for data in responses2:
   if data["Response"] == "True":
        try:
            Title.append(data["Title"])
        except:
            Title.append('N/A')
        try:        
            Year.append(data["Year"])
        except:
            Year.append('N/A')
        try:        
            Rated.append(data["Rated"])
        except:
            Rated.append('N/A')        
        try:        
            Released.append(data["Released"])
        except:
            Released.append('N/A')     
        try:        
            Runtime.append(data["Runtime"])
        except:
            Runtime.append('N/A')   
        try:
            Genre.append(data["Genre"])
        except:
            Genre.append('N/A')
        try:
            Director.append(data["Director"])
        except:
            Director.append('N/A')
        try:
            Writer.append(data["Writer"])
        except:
            Writer.append('N/A')   
        try:
            Actors.append(data["Actors"])
        except:
            Actors.append('N/A')
        try:
            Language.append(data["Language"])
        except:
            Language.append('N/A')            
        try:
            Country.append(data["Country"])
        except:
            Country.append('N/A')
        try:
            IMDB.append(data["Ratings"][0]["Value"])
        except:
            IMDB.append('N/A')
        try:
            RottenTomatoes.append(data["Ratings"][1]["Value"])
        except:
            RottenTomatoes.append('N/A')
        try:
            Metacritic.append(data["Ratings"][2]["Value"])
        except:
            Metacritic.append('N/A')
        try:
            Type.append(data["Type"])
        except:
            Type.append('N/A')
        try:
            BoxOffice.append(data["BoxOffice"])
        except:
            BoxOffice.append('N/A')
        try:
            Production.append(data["Production"])
        except:
            Production.append('N/A')

# %%
#Pulls data from the json file (response) and adds the data into the empty lists 
for data in responses3:
   if data["Response"] == "True":
        try:
            Title.append(data["Title"])
        except:
            Title.append('N/A')
        try:        
            Year.append(data["Year"])
        except:
            Year.append('N/A')
        try:        
            Rated.append(data["Rated"])
        except:
            Rated.append('N/A')        
        try:        
            Released.append(data["Released"])
        except:
            Released.append('N/A')     
        try:        
            Runtime.append(data["Runtime"])
        except:
            Runtime.append('N/A')   
        try:
            Genre.append(data["Genre"])
        except:
            Genre.append('N/A')
        try:
            Director.append(data["Director"])
        except:
            Director.append('N/A')
        try:
            Writer.append(data["Writer"])
        except:
            Writer.append('N/A')   
        try:
            Actors.append(data["Actors"])
        except:
            Actors.append('N/A')
        try:
            Language.append(data["Language"])
        except:
            Language.append('N/A')            
        try:
            Country.append(data["Country"])
        except:
            Country.append('N/A')
        try:
            IMDB.append(data["Ratings"][0]["Value"])
        except:
            IMDB.append('N/A')
        try:
            RottenTomatoes.append(data["Ratings"][1]["Value"])
        except:
            RottenTomatoes.append('N/A')
        try:
            Metacritic.append(data["Ratings"][2]["Value"])
        except:
            Metacritic.append('N/A')
        try:
            Type.append(data["Type"])
        except:
            Type.append('N/A')
        try:
            BoxOffice.append(data["BoxOffice"])
        except:
            BoxOffice.append('N/A')
        try:
            Production.append(data["Production"])
        except:
            Production.append('N/A')

# %%
#Pulls data from the json file (response) and adds the data into the empty lists 
for data in responses6:
   if data["Response"] == "True":
        try:
            Title.append(data["Title"])
        except:
            Title.append('N/A')
        try:        
            Year.append(data["Year"])
        except:
            Year.append('N/A')
        try:        
            Rated.append(data["Rated"])
        except:
            Rated.append('N/A')        
        try:        
            Released.append(data["Released"])
        except:
            Released.append('N/A')     
        try:        
            Runtime.append(data["Runtime"])
        except:
            Runtime.append('N/A')   
        try:
            Genre.append(data["Genre"])
        except:
            Genre.append('N/A')
        try:
            Director.append(data["Director"])
        except:
            Director.append('N/A')
        try:
            Writer.append(data["Writer"])
        except:
            Writer.append('N/A')   
        try:
            Actors.append(data["Actors"])
        except:
            Actors.append('N/A')
        try:
            Language.append(data["Language"])
        except:
            Language.append('N/A')            
        try:
            Country.append(data["Country"])
        except:
            Country.append('N/A')
        try:
            IMDB.append(data["Ratings"][0]["Value"])
        except:
            IMDB.append('N/A')
        try:
            RottenTomatoes.append(data["Ratings"][1]["Value"])
        except:
            RottenTomatoes.append('N/A')
        try:
            Metacritic.append(data["Ratings"][2]["Value"])
        except:
            Metacritic.append('N/A')
        try:
            Type.append(data["Type"])
        except:
            Type.append('N/A')
        try:
            BoxOffice.append(data["BoxOffice"])
        except:
            BoxOffice.append('N/A')
        try:
            Production.append(data["Production"])
        except:
            Production.append('N/A')

# %%
#Pulls data from the json file (response) and adds the data into the empty lists 
for data in responses4:
   if data["Response"] == "True":
        try:
            Title.append(data["Title"])
        except:
            Title.append('N/A')
        try:        
            Year.append(data["Year"])
        except:
            Year.append('N/A')
        try:        
            Rated.append(data["Rated"])
        except:
            Rated.append('N/A')        
        try:        
            Released.append(data["Released"])
        except:
            Released.append('N/A')     
        try:        
            Runtime.append(data["Runtime"])
        except:
            Runtime.append('N/A')   
        try:
            Genre.append(data["Genre"])
        except:
            Genre.append('N/A')
        try:
            Director.append(data["Director"])
        except:
            Director.append('N/A')
        try:
            Writer.append(data["Writer"])
        except:
            Writer.append('N/A')   
        try:
            Actors.append(data["Actors"])
        except:
            Actors.append('N/A')
        try:
            Language.append(data["Language"])
        except:
            Language.append('N/A')            
        try:
            Country.append(data["Country"])
        except:
            Country.append('N/A')
        try:
            IMDB.append(data["Ratings"][0]["Value"])
        except:
            IMDB.append('N/A')
        try:
            RottenTomatoes.append(data["Ratings"][1]["Value"])
        except:
            RottenTomatoes.append('N/A')
        try:
            Metacritic.append(data["Ratings"][2]["Value"])
        except:
            Metacritic.append('N/A')
        try:
            Type.append(data["Type"])
        except:
            Type.append('N/A')
        try:
            BoxOffice.append(data["BoxOffice"])
        except:
            BoxOffice.append('N/A')
        try:
            Production.append(data["Production"])
        except:
            Production.append('N/A')

# %%
#Pulls data from the json file (response) and adds the data into the empty lists 
for data in responses5:
   if data["Response"] == "True":
        try:
            Title.append(data["Title"])
        except:
            Title.append('N/A')
        try:        
            Year.append(data["Year"])
        except:
            Year.append('N/A')
        try:        
            Rated.append(data["Rated"])
        except:
            Rated.append('N/A')        
        try:        
            Released.append(data["Released"])
        except:
            Released.append('N/A')     
        try:        
            Runtime.append(data["Runtime"])
        except:
            Runtime.append('N/A')   
        try:
            Genre.append(data["Genre"])
        except:
            Genre.append('N/A')
        try:
            Director.append(data["Director"])
        except:
            Director.append('N/A')
        try:
            Writer.append(data["Writer"])
        except:
            Writer.append('N/A')   
        try:
            Actors.append(data["Actors"])
        except:
            Actors.append('N/A')
        try:
            Language.append(data["Language"])
        except:
            Language.append('N/A')            
        try:
            Country.append(data["Country"])
        except:
            Country.append('N/A')
        try:
            IMDB.append(data["Ratings"][0]["Value"])
        except:
            IMDB.append('N/A')
        try:
            RottenTomatoes.append(data["Ratings"][1]["Value"])
        except:
            RottenTomatoes.append('N/A')
        try:
            Metacritic.append(data["Ratings"][2]["Value"])
        except:
            Metacritic.append('N/A')
        try:
            Type.append(data["Type"])
        except:
            Type.append('N/A')
        try:
            BoxOffice.append(data["BoxOffice"])
        except:
            BoxOffice.append('N/A')
        try:
            Production.append(data["Production"])
        except:
            Production.append('N/A')

# %%
#Creates DF with the lists
Movie1DF = pd.DataFrame({"Title": Title,
                         "Year": Year,
                         "Rated": Rated,
                         "Released": Released,
                         "Runtime": Runtime,
                         "Genre": Genre,
                         "Director": Director,
                         "Writer": Writer,
                         "Actors": Actors,
                         "Language": Language,
                         "Country": Country,
                         "IMDB": IMDB,
                         "Rotten Tomatoes": RottenTomatoes,
                         "Metacritic": Metacritic,
                         "Box Office": BoxOffice,
                         "Type": Type,
                         "Production": Production
                        })

# %%
len(Movie1DF)
# Out:
# 5838

# %%
Movie1DF

# %%
Movie1DF.to_csv(r'Movies_DF.csv')
