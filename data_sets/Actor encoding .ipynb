# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import make_blobs
# read file
df = pd.read_csv("combined3.csv")

# how to convert pandas dataframe to a numpy array

# X, y = make_blobs(centers=2, random_state=42)

# print(f"Labels: {y[:10]}")
# print(f"Data: {X[:10]}")

# %%
df.head()
# Out:
#    Unnamed: 0                     Title  \
# 0           0              Pulp Fiction
# 1           1  The Amazing Spider-Man 2
# 2           2  The Shawshank Redemption
# 3           3        Back to the Future
# 4           4        The Breakfast Club
#
#                                               Actors   Box Office Country  \
# 0  Tim Roth, Amanda Plummer, Laura Lovelace, John...          NaN     USA
# 1  Andrew Garfield, Emma Stone, Jamie Foxx, Dane ...  183277573.0     USA
# 2  Tim Robbins, Morgan Freeman, Bob Gunton, Willi...          NaN     USA
# 3  Michael J. Fox, Christopher Lloyd, Lea Thompso...    2925880.0     USA
# 4  Emilio Estevez, Paul Gleason, Anthony Michael ...          NaN     USA
#
#             Director                      Genre    IMDB  \
# 0  Quentin Tarantino               Crime, Drama  8.9/10
# 1          Marc Webb  Action, Adventure, Sci-Fi  6.6/10
# 2     Frank Darabont                      Drama  9.3/10
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'Actors', 'Box Office', 'Country', 'Director',
#        'Genre', 'IMDB', 'Language', 'Metacritic', 'Production', 'Rated',
#        'Released', 'Rotten Tomatoes', 'Runtime', 'Type', 'Writer', 'Year',
#        'Unnamed: 0.1', 'Rank', 'Release Year', 'Worldwide Box Office',
#        'Domestic Box Office', 'International Box Office', 'Awards',
#        'Nominations'],
#       dtype='object')

# %%
df[['Genre', 'Director', 'Box Office','Language','Country','IMDB', 'Metacritic','Rank','Awards', 'Worldwide Box Office', 'Domestic Box Office', 'International Box Office']]
# Out:
#                                               Genre  \
# 0                                      Crime, Drama
# 1                         Action, Adventure, Sci-Fi
# 2                                             Drama
# 3                         Adventure, Comedy, Sci-Fi
# 4                                     Comedy, Drama
# 5                         Adventure, Comedy, Family
# 6                            Crime, Drama, Thriller
# 7                       Adventure, Sci-Fi, Thriller
# 8      Animation, Adventure, Drama, Family, Musical
# 9                   Crime, Drama, Mystery, Thriller
# 10    Animation, Adventure, Comedy, Family, Fantasy
# 11                                    Comedy, Crime
# 12                                       Drama, War
# 13                                            Drama
# 14                                   Action, Sci-Fi
# 15                         Action, Adventure, Drama
# 16                         Action, Adventure, Drama
# ...

# %%
actors=[]
for i in np.array(df['Actors'].apply(lambda x: x.split(','))):
    for j in i:
        actors.append(j.strip())
actors
# Out:
# ['Tim Roth',
#  'Amanda Plummer',
#  'Laura Lovelace',
#  'John Travolta',
#  'Andrew Garfield',
#  'Emma Stone',
#  'Jamie Foxx',
#  'Dane DeHaan',
#  'Tim Robbins',
#  'Morgan Freeman',
#  'Bob Gunton',
#  'William Sadler',
#  'Michael J. Fox',
#  'Christopher Lloyd',
#  'Lea Thompson',
#  'Crispin Glover',
#  'Emilio Estevez',
#  'Paul Gleason',
#  'Anthony Michael Hall',
#  'John Kapelos',
#  'Sean Astin',
#  'Josh Brolin',
#  'Jeff Cohen',
#  'Corey Feldman',
#  'Jodie Foster',
#  'Lawrence A. Bonney',
#  'Kasi Lemmons',
#  'Lawrence T. Wrentz',
#  'Sam Neill',
#  'Laura Dern',
#  'Jeff Goldblum',
#  'Richard Attenborough',
#  'Rowan Atkinson',
#  'Matthew Broderick',
#  'Niketa Calame-Harris',
#  'Jim Cummings',
#  'Morgan Freeman',
#  'Andrew Kevin Walker',
#  'Daniel Zacapa',
#  'Brad Pitt',
#  'Tom Hanks',
#  'Tim Allen',
#  'Don Rickles',
#  'Jim Varney',
#  'Jeff Bridges',
#  'John Goodman',
#  'Julianne Moore',
#  'Steve Buscemi',
#  'Tom Hanks',
#  'Tom Sizemore',
# ...

# %%
df['Actors']
# Out:
# 0       Tim Roth, Amanda Plummer, Laura Lovelace, John...
# 1       Andrew Garfield, Emma Stone, Jamie Foxx, Dane ...
# 2       Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 3       Michael J. Fox, Christopher Lloyd, Lea Thompso...
# 4       Emilio Estevez, Paul Gleason, Anthony Michael ...
# 5       Sean Astin, Josh Brolin, Jeff Cohen, Corey Fel...
# 6       Jodie Foster, Lawrence A. Bonney, Kasi Lemmons...
# 7       Sam Neill, Laura Dern, Jeff Goldblum, Richard ...
# 8       Rowan Atkinson, Matthew Broderick, Niketa Cala...
# 9       Morgan Freeman, Andrew Kevin Walker, Daniel Za...
# 10          Tom Hanks, Tim Allen, Don Rickles, Jim Varney
# 11      Jeff Bridges, John Goodman, Julianne Moore, St...
# 12      Tom Hanks, Tom Sizemore, Edward Burns, Barry P...
# 13      Edward Norton, Brad Pitt, Meat Loaf, Zach Grenier
# 14      Keanu Reeves, Laurence Fishburne, Carrie-Anne ...
# 15      Russell Crowe, Joaquin Phoenix, Connie Nielsen...
# ...

# %%
for i in np.array(df['Actors'].apply(lambda x: x.split(','))):
    actors1=[]
    xx = 0
    for j in i:
        if xx<=2:
            actors1.append(j.strip())
        xx = xx+1

# %%
for i in np.array(df['Actors'].apply(lambda x: x.split(','))):
    print (i)
#     actors1=[]
#     xx = 0
#     for j in i:
#         if xx<=2:
#             actors1.append(j.strip())
#         xx = xx+1
# Out:
# ['Tim Roth', ' Amanda Plummer', ' Laura Lovelace', ' John Travolta']
# ['Andrew Garfield', ' Emma Stone', ' Jamie Foxx', ' Dane DeHaan']
# ['Tim Robbins', ' Morgan Freeman', ' Bob Gunton', ' William Sadler']
# ['Michael J. Fox', ' Christopher Lloyd', ' Lea Thompson', ' Crispin Glover']
# ['Emilio Estevez', ' Paul Gleason', ' Anthony Michael Hall', ' John Kapelos']
# ['Sean Astin', ' Josh Brolin', ' Jeff Cohen', ' Corey Feldman']
# ['Jodie Foster', ' Lawrence A. Bonney', ' Kasi Lemmons', ' Lawrence T. Wrentz']
# ['Sam Neill', ' Laura Dern', ' Jeff Goldblum', ' Richard Attenborough']
# ['Rowan Atkinson', ' Matthew Broderick', ' Niketa Calame-Harris', ' Jim Cummings']
# ['Morgan Freeman', ' Andrew Kevin Walker', ' Daniel Zacapa', ' Brad Pitt']
# ['Tom Hanks', ' Tim Allen', ' Don Rickles', ' Jim Varney']
# ['Jeff Bridges', ' John Goodman', ' Julianne Moore', ' Steve Buscemi']
# ['Tom Hanks', ' Tom Sizemore', ' Edward Burns', ' Barry Pepper']
# ...

# %%
actors1
# Out:
# ['Jack Lemmon', 'Walter Matthau', 'Susan Sarandon']

# %%
df['Actors2'] = np.nan
for index, row in df.iterrows():
#     print(df['Actors'][index])
#     print(", ".join(row['Actors'].split(", ")[0:3]))
    print(df['Actors'][index].split(", ")[0:3])
    df['Actors2'][index] = row['Actors'].split(", ")[0:3]
df['Actors2']
# Out:
# ['Tim Roth', 'Amanda Plummer', 'Laura Lovelace']
# ['Andrew Garfield', 'Emma Stone', 'Jamie Foxx']
# ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']
# ['Michael J. Fox', 'Christopher Lloyd', 'Lea Thompson']
# ['Emilio Estevez', 'Paul Gleason', 'Anthony Michael Hall']
# ['Sean Astin', 'Josh Brolin', 'Jeff Cohen']
# ['Jodie Foster', 'Lawrence A. Bonney', 'Kasi Lemmons']
# ['Sam Neill', 'Laura Dern', 'Jeff Goldblum']
# ['Rowan Atkinson', 'Matthew Broderick', 'Niketa Calame-Harris']
# ['Morgan Freeman', 'Andrew Kevin Walker', 'Daniel Zacapa']
# ['Tom Hanks', 'Tim Allen', 'Don Rickles']
# ['Jeff Bridges', 'John Goodman', 'Julianne Moore']
# ['Tom Hanks', 'Tom Sizemore', 'Edward Burns']
# ['Edward Norton', 'Brad Pitt', 'Meat Loaf']
# ['Keanu Reeves', 'Laurence Fishburne', 'Carrie-Anne Moss']
# ['Russell Crowe', 'Joaquin Phoenix', 'Connie Nielsen']
# ['Russell Crowe', 'Joaquin Phoenix', 'Connie Nielsen']
# ['Hugh Jackman', 'Patrick Stewart', 'Ian McKellen']
# ...

# %%
df.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x11cea41a8>

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(actors)
# LabelEncoder()
list(le.classes_)
# ['amsterdam', 'paris', 'tokyo']
# Out:
# ['50 Cent',
#  'A.C. Peterson',
#  'A.D. Miles',
#  'A.J. Cook',
#  'A.J. Langer',
#  'Aaliyah',
#  'Aaran Thomas',
#  'Aaron Benjamin',
#  'Aaron Eckhart',
#  'Aaron Ruell',
#  'Aaron Stanford',
#  'Aaron Taylor-Johnson',
#  'Aaron Yoo',
#  'Aasif Mandvi',
#  'Abbie Cornish',
#  'Abbie Glozier',
#  'Abe Vigoda',
#  'Abhay Deol',
#  'Abhishek Bachchan',
#  'Abigail Breslin',
#  'Abigail Spencer',
#  'Abraham Benrubi',
#  'Abram Rooney',
#  'Achita Sikamana',
#  'Adam Baldwin',
#  'Adam Barrie',
#  'Adam Beach',
#  'Adam Bengis',
#  'Adam Boyer',
#  'Adam Brody',
#  'Adam Brooks',
#  'Adam Bryant',
#  'Adam C. Edwards',
#  'Adam Campbell',
#  'Adam Cockburn',
#  'Adam Deacon',
#  'Adam Garcia',
#  'Adam Hann-Byrd',
#  'Adam Herschman',
#  'Adam Hicks',
#  'Adam Lamberg',
#  'Adam LeFevre',
#  'Adam Marcello',
#  'Adam Pascal',
#  'Adam Rayner',
#  'Adam Rothenberg',
#  'Adam Sandler',
#  'Adam Scott',
#  'Adam Trese',
#  'Addison Timlin',
#  'Adelaide Kane',
#  'Aden Young',
# ...

# %%
print(df['Actors2'][1])
le.transform(df['Actors2'][1]) 
# array([2, 2, 1]...)
# list(le.inverse_transform([2, 2, 1]))
# ['tokyo', 'tokyo', 'paris']
# Out:
# ['Andrew Garfield', 'Emma Stone', 'Jamie Foxx']
# array([ 293, 1811, 2535])

# %%
df['Actors_1'] = np.nan
df['Actors_2'] = np.nan
df['Actors_3'] = np.nan
for index, row in df.iterrows():
#     print(df['Actors'][index])
#     print(", ".join(row['Actors'].split(", ")[0:3]))
#     print(df['Actors'][index].split(", ")[0:3])
#     print(le.transform([row['Actors'].split(", ")[0]]))
    df['Actors_1'][index] = le.transform([row['Actors'].split(", ")[0]])
    df['Actors_2'][index] = le.transform([row['Actors'].split(", ")[1]])
    df['Actors_3'][index] = le.transform([row['Actors'].split(", ")[2]])
# df['Actors2']
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                     Title  \
# 0           0              Pulp Fiction
# 1           1  The Amazing Spider-Man 2
# 2           2  The Shawshank Redemption
# 3           3        Back to the Future
# 4           4        The Breakfast Club
#
#                                               Actors   Box Office Country  \
# 0  Tim Roth, Amanda Plummer, Laura Lovelace, John...          NaN     USA
# 1  Andrew Garfield, Emma Stone, Jamie Foxx, Dane ...  183277573.0     USA
# 2  Tim Robbins, Morgan Freeman, Bob Gunton, Willi...          NaN     USA
# 3  Michael J. Fox, Christopher Lloyd, Lea Thompso...    2925880.0     USA
# 4  Emilio Estevez, Paul Gleason, Anthony Michael ...          NaN     USA
#
#             Director                      Genre    IMDB  \
# 0  Quentin Tarantino               Crime, Drama  8.9/10
# 1          Marc Webb  Action, Adventure, Sci-Fi  6.6/10
# 2     Frank Darabont                      Drama  9.3/10
# ...

# %%
df.to_csv("Actors_Encoded.csv")
